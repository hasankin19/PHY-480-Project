# %% [markdown]
# # PHY480/905 Semester Project Template

# %% [markdown]
# **INSTRUCTIONS**: This is a template to help organize your project.  All projects must include the 5 major sections below (you do not need to use this template file).  Complete your work below and remove content in parentheses.

# %% [markdown]
# #### PHY 480/905 Semester Project
# ### &#9989; Kinza Hasan)
# #### &#9989; Last Updated on WHAT DATE

# %% [markdown]
# # Van der Pol Oscillator

# %% [markdown]
# ##  introduction

# %% [markdown]
# _(Provide context for the problem: Background and Motivation.
#
#
# Van Der Pol Oscillator:
#
# $\frac{d^2x}{dt^2} - \mu(1-x^2)\frac{dx}{dt} +\beta x =F(sin(\alpha t)$
#
# **Clearly state the question(s) you set
# out to answer.**)_

# %% [markdown]
# ## Methodology

# %% [markdown]
# _(How did you go about answering your question(s)? Most of your code will be
# contained in this section.)_

# %%
import numpy as np
from math import *
import matplotlib.pyplot as plt
import pandas as pd
import os

import time
from IPython.display import clear_output
# %matplotlib inline

# %%
#Numerical solutions:

def VDPO(mu,X, V):
    dX = V
    dV = mu*(1-X**2)*V - X
    return dX, dV
# Looking at the yssytem where mu is zero to see the most relaible integration method to compare it with the analytical

# %%
Act=np.cos(t)
#Actual solution

# %%
#RK 2
def RK(f,tf,n,mu):
    v=0
    x=1
    X_values=[]
    V_values=[]
    h=tf/n
    tpoints = np.arange(0,tf,h)
    for t in tpoints:
        X_values.append(x)
        V_values.append(v)
        k1x,k1v = f(mu,x,v)
        k2x,k2v =f(mu,x+h*k1x,v+ h*k1v)
        x +=  h*(k2x+k1x)/2
        v+= h*(k2v+k1v)/2
    return tpoints,X_values, V_values

# %%
#Testing convergencee by increasing number of time steps:
tsteps=[100,1000,10000,100000]
mean_err=[]
max_err=[]
for ts in tsteps:
    trk,xrk,vrk=RK(VDPO,20,ts,0)
    Act=np.cos(trk)
    max_err.append(np.max(np.abs(xrk-Act)))
    mean_err.append(np.mean(np.abs(xrk-Act)))

# %%
plt.plot(tsteps,mean_err,label='mean error')
plt.plot(tsteps,mean_err,label='max error')
plt.yscale('log')
plt.xscale('log')
plt.legend()
plt.show()

# %%
trkut,xrkut,vrkut=RK(VDPO,20,1000000,0)

# %%
def RK4(f, tf, n, mu):
    v = 0
    x = 1
    X_values = []
    V_values = []
    h = tf / n
    tpoints = np.arange(0, tf, h)
    for t in tpoints:
        X_values.append(x)
        V_values.append(v)
        
        k1x, k1v = f(mu, x, v)
    
        k2x, k2v = f(mu, x + h / 2 * k1x, v + h / 2 * k1v)
    
        k3x, k3v = f(mu, x + h / 2 * k2x, v + h / 2 * k2v)
    
        k4x, k4v = f(mu, x + h * k3x, v + h * k3v)
    
        x += h / 6 * (k1x + 2 * k2x + 2 * k3x + k4x)
        v += h / 6 * (k1v + 2 * k2v + 2 * k3v + k4v)
        
    return tpoints, X_values, V_values

# %%
tsteps=[100,1000,10000,100000]
mean_err=[]
max_err=[]
for ts in tsteps:
    trk,xrk,vrk=RK4(VDPO,20,ts,0)
    Act=np.cos(trk)
    max_err.append(np.max(np.abs(xrk-Act)))
    mean_err.append(np.mean(np.abs(xrk-Act)))
plt.plot(tsteps,mean_err,label='mean error')
plt.plot(tsteps,mean_err,label='max error')
plt.yscale('log')
plt.xscale('log')
plt.legend()
plt.show()

# %%
trk4,xrk4,vrk4=RK4(VDPO,20,1000000,0)

# %%
import numpy as np

def RK45(f, tf, n, mu):
    v = 0
    x = 1
    x_values = []
    v_values = []
    h = tf / n
    tpoints = np.arange(0, tf, h)
    for t in tpoints:
        x_values.append(x)
        v_values.append(v)

        
        k1x, k1v = f(mu, x, v)
        k2x, k2v = f(mu, x + h * k1x / 4, v + h * k1v / 4)
        k3x, k3v = f(mu, x + 3 * h * k1x / 32 + 9 * h * k2x / 32, v + 3 * h * k1v / 32 + 9 * h * k2v / 32)
        k4x, k4v = f(mu, x + 1932 * h * k1x / 2197 - 7200 * h * k2x / 2197 + 7296 * h * k3x / 2197,
                     v + 1932 * h * k1v / 2197 - 7200 * h * k2v / 2197 + 7296 * h * k3v / 2197)
        k5x, k5v = f(mu, x + h * (439 * k1x / 216 - 8 * k2x + 3680 * k3x / 513 - 845 * k4x / 4104),
                     v + h * (439 * k1v / 216 - 8 * k2v + 3680 * k3v / 513 - 845 * k4v / 4104))
        k6x, k6v = f(mu, x - 8 * h * k1x / 27 + 2 * h * k2x / 3 - 3544 * h * k3x / 2565 + 1859 * h * k4x / 4104
                     - 11 * h * k5x / 40, v - 8 * h * k1v / 27 + 2 * h * k2v / 3 - 3544 * h * k3v / 2565
                     + 1859 * h * k4v / 4104 - 11 * h * k5v / 40)

        x += h * (25 * k1x / 216 + 1408 * k3x / 2565 + 2197 * k4x / 4104 - k5x / 5)
        v += h * (25 * k1v / 216 + 1408 * k3v / 2565 + 2197 * k4v / 4104 - k5v / 5)

    return tpoints, x_values, v_values



#https://math.okstate.edu/people/yqwang/teaching/math4513_fall11/Notes/rungekutta.pdf

# %%
tsteps=[100,1000,10000,100000]
mean_err=[]
max_err=[]
for ts in tsteps:
    trk,xrk,vrk=RK45(VDPO,20,ts,0)
    Act=np.cos(trk)
    max_err.append(np.max(np.abs(xrk-Act)))
    mean_err.append(np.mean(np.abs(xrk-Act)))
plt.plot(tsteps,mean_err,label='mean error')
plt.plot(tsteps,mean_err,label='max error')
plt.yscale('log')
plt.xscale('log')
plt.legend()
plt.show()

# %%
trk45,xrk45,vrk45= RK45(VDPO, 20, 1000000, 0)

# %%
def euler(f, tf, n, mu):
    V_values = [0]  # Initial condition for V
    X_values = [1]  # Initial condition for X
    h = tf / n
    tpoints = np.arange(0, tf, h)
    for t in tpoints[1:]:
        X, V = X_values[-1], V_values[-1]
        
        # Calculate derivatives at the current point
        dX, dV = f(mu, X, V)
        
        # Update X and V using Euler's method
        X_new = X + h * dX
        V_new = V + h * dV
        
        # Append the new values to the lists
        X_values.append(X_new)
        V_values.append(V_new)
        
    return tpoints, X_values, V_values

# %%
tsteps=[100,1000,10000,100000]
mean_err=[]
max_err=[]
for ts in tsteps:
    trk,xrk,vrk=euler(VDPO,20,ts,0)
    Act=np.cos(trk)
    max_err.append(np.max(np.abs(xrk-Act)))
    mean_err.append(np.mean(np.abs(xrk-Act)))
plt.plot(tsteps,mean_err,label='mean error')
plt.plot(tsteps,mean_err,label='max error')
plt.yscale('log')
plt.xscale('log')
plt.legend()
plt.show()

# %%
te,xe,ve=euler(VDPO,20,1000000,0)

# %%
def AB2(f, tf, n, mu):
    v = 0
    x = 1
    X_values = []
    V_values = []
    h = tf / n
    tpoints = np.arange(0, tf, h)
 
    X_values.append(x)
    V_values.append(v)
    k1x, k1v = f(mu, x, v)
    v += h * k1v
    x += h * (v + h / 2 * k1v)
    
    X_values.append(x)
    V_values.append(v)
    k2x, k2v = f(mu, x, v)
    v += h * k2v
    x += h * (v + h / 2 * k2v)
    
    for t in tpoints[2:]:
        X_values.append(x)
        V_values.append(v)
  
        fn_minus_1_x, fn_minus_1_v = f(mu, X_values[-2], V_values[-2])
        fn_x, fn_v = f(mu, X_values[-1], V_values[-1])
        
        x += h / 2 * (3 * fn_x - fn_minus_1_x)
        v += h / 2 * (3 * fn_v - fn_minus_1_v)
        
    return tpoints, X_values, V_values
#https://john-s-butler-dit.github.io/NumericalAnalysisBook/Chapter%2004%20-%20Multistep%20Methods/402_Adams%20Bashforth%20Population%20Equations.html

# %%
tsteps=[100,1000,10000,100000]
mean_err=[]
max_err=[]
for ts in tsteps:
    trk,xrk,vrk=AB2(VDPO,20,ts,0)
    Act=np.cos(trk)
    max_err.append(np.max(np.abs(xrk-Act)))
    mean_err.append(np.mean(np.abs(xrk-Act)))
plt.plot(tsteps,mean_err,label='mean error')
plt.plot(tsteps,mean_err,label='max error')
plt.yscale('log')
plt.xscale('log')
plt.legend()
plt.show()

# %%
tab2,xab2,vab2=AB2(VDPO,20,1000000,0)

# %%
#Adams-Bashforth
def AB4(f, tf, n, mu):
    v = 0
    x = 1
    X_values = []
    V_values = []
    h = tf / n
    tpoints = np.arange(0, tf, h)
    
    for _ in range(3):
        X_values.append(x)
        V_values.append(v)
        k1x, k1v = f(mu, x, v)
        v += h * k1v
        x += h * (v + h / 2 * k1v)
    
    for t in tpoints[3:]:
        X_values.append(x)
        V_values.append(v)
       
        fn_minus_1_x, fn_minus_1_v = f(mu, X_values[-2], V_values[-2])
        fn_minus_2_x, fn_minus_2_v = f(mu, X_values[-3], V_values[-3])
        fn_minus_3_x, fn_minus_3_v = f(mu, X_values[-4], V_values[-4])
        
        fn_x, fn_v = f(mu, X_values[-1], V_values[-1])
        
        x += h / 24 * (55 * fn_x - 59 * fn_minus_1_x + 37 * fn_minus_2_x - 9 * fn_minus_3_x)
        v += h / 24 * (55 * fn_v - 59 * fn_minus_1_v + 37 * fn_minus_2_v - 9 * fn_minus_3_v)
        
    return tpoints, X_values, V_values
#https://en.wikipedia.org/wiki/Linear_multistep_method

# %%
tsteps=[100,1000,10000,100000]
mean_err=[]
max_err=[]
for ts in tsteps:
    trk,xrk,vrk=AB4(VDPO,20,ts,0)
    Act=np.cos(trk)
    max_err.append(np.max(np.abs(xrk-Act)))
    mean_err.append(np.mean(np.abs(xrk-Act)))
plt.plot(tsteps,mean_err,label='mean error')
plt.plot(tsteps,mean_err,label='max error')
plt.yscale('log')
plt.xscale('log')
plt.legend()
plt.show()

# %%
tab4,xab4,vab4=AB4(VDPO,20,1000000,0)

# %%
t=np.arange(0,20,20/1000000)
plt.plot(t,np.cos(t),label='Analytical')
plt.plot(t,xrkut,label='Runga-Kutta 2')
plt.plot(t,xe,label='euler')
plt.plot(trk4,xrk4,label='Runga-Kutta 4')
plt.plot(trk45,xrk45,label='Runga-Kutta 4-5')
plt.plot(t,xab2,label='Adams 2')
plt.plot(t,xab4,label='Adams 4',color='pink')
plt.legend()
plt.show()

# %%
Act=np.cos(t)
plt.plot(t,xrkut-Act,label='Runga-Kutta 2')
plt.plot(t,xrk4-Act,label='Runga-Kutta 4')
plt.plot(t,xab2-Act,label='Adams 2')
plt.plot(t,xab4-Act,label='Adams 4',color='pink')
plt.plot(t,xrk45-Act,label='runga kutta 45',color='purple')

#plt.plot(t,xe-Act,label='euler',color='purple')

# %%
#MEAN ERROR CALCULATION
mean_errors = {
    "Runga-kutta-2": np.mean(np.abs(xrkut-Act)),
    "Runga-kutta-4": np.mean(np.abs(xrk4-Act)),
    "Runga-kutta-45": np.mean(np.abs(xrk45-Act)),
    "Adams-Bashforth-2": np.mean(np.abs(xab2-Act)),
    "Adams-Bashforth-4": np.mean(np.abs(xab4-Act)),
    "Euler": np.mean(np.abs(xe-Act))
}
mean_errors
# Out:
# {'Runga-kutta-2': 4.156700765134582e-10,
#  'Runga-kutta-4': 1.8397444364399766e-14,
#  'Runga-kutta-45': 1.9211116836308606e-14,
#  'Adams-Bashforth-2': 1.2109266181654465e-09,
#  'Adams-Bashforth-4': 7.747936771323581e-10,
#  'Euler': 6.538656996656807e-05}

# %%
#Max errors:
max_errors = {
    "Runga-kutta-2": np.max(np.abs(xrkut-Act)),
    "Runga-kutta-4": np.max(np.abs(xrk4-Act)),
    "Runga-kutta-45": np.max(np.abs(xrk45-Act)),
    "Adams-Bashforth-2": np.max(np.abs(xab2-Act)),
    "Adams-Bashforth-4": np.max(np.abs(xab4-Act)),
    "Euler": np.max(np.abs(xe-Act))
}
max_errors
# Out:
# {'Runga-kutta-2': 1.2172624019868294e-09,
#  'Runga-kutta-4': 4.729550084903167e-14,
#  'Runga-kutta-45': 4.9960036108132044e-14,
#  'Adams-Bashforth-2': 3.369624801408122e-09,
#  'Adams-Bashforth-4': 1.2000407334511465e-09,
#  'Euler': 0.0001887781114034981}

# %%
#FINAL RESULT: We will use Runga Kutta-4 for when mu is not zero!

# %%
#Analysis for mu
mus=[0.01,0.1,0.5]
for mu in mus:
    trk4,xrk4,vrk4=RK4(VDPO,50,100000,mu)
    plt.plot(trk4,xrk4,label=f'mu is {mu}')
plt.legend()
plt.show()

# %%
mus=[1,5,10,15]
for mu in mus:
    trk4,xrk4,vrk4=RK4(VDPO,50,100000,mu)
    plt.plot(trk4,xrk4,label=f'mu is {mu}')
plt.legend()
plt.show()

# %%
#Animation as to how mu changes:
mus=[0.01,0.1,0.5,1,5,10,15,20]
fig = plt.figure(figsize=(8,8))
# Generate and save images
for mu in mus:
    trk4,xrk4,vrk4=RK4(VDPO,50,100000,mu)
    plt.plot(trk4,xrk4,color='purple')
    plt.title(f'mu is {mu}')
    plt.xlabel('t')
    plt.ylabel('x')
    time.sleep(0.01)
    
    clear_output(wait = True)
    display(fig)            # Reset display
    fig.clear()

# %%
mus=[0.01,0.1,0.5]
for mu in mus:
    trk4,xrk4,vrk4=RK4(VDPO,20,100000,mu)
    plt.plot(trk4,vrk4,label=f'mu is {mu}')
plt.legend()
plt.show()

# %%
mus=[1,10,15]
for mu in mus:
    trk4,xrk4,vrk4=RK4(VDPO,20,100000,mu)
    plt.plot(trk4,vrk4,label=f'mu is {mu}')
plt.legend()
plt.show()

# %%
mus=[0.01,0.1,0.5,1,5,10,15,20]
fig = plt.figure(figsize=(8,8))
# Generate and save images
for mu in mus:
    trk4,xrk4,vrk4=RK4(VDPO,50,100000,mu)
    plt.plot(trk4,vrk4,color='purple')
    plt.title(f'mu is {mu}')
    plt.xlabel('t')
    plt.ylabel('v')
    time.sleep(0.01)
    #plt.ylim(-30,30)
    
    clear_output(wait = True)
    display(fig)            # Reset display
    fig.clear()

# %%
mus=[0.01,0.1,0.5,1]
#mus=[0.1,1,10]
for mu in mus:
    trk4,xrk4,vrk4=RK4(VDPO,20,100000,mu)
    plt.plot(xrk4,vrk4,label=f'mu is {mu}')
plt.legend()
plt.show()

# %%
mus=[10,15,20]
for mu in mus:
    trk4,xrk4,vrk4=RK4(VDPO,20,100000,mu)
    plt.plot(xrk4,vrk4,label=f'mu is {mu}')
plt.legend()
plt.show()

# %%
#Animation as to how mu changes:
mus=[0.01,0.1,0.5,1,5,10,15,20]
fig = plt.figure(figsize=(8,8))
# Generate and save images
for mu in mus:
    trk4,xrk4,vrk4=RK4(VDPO,50,100000,mu)
    plt.plot(xrk4,vrk4,color='purple')
    plt.title(f'mu is {mu}')
    plt.xlabel('x')
    plt.ylabel('v')
    time.sleep(0.01)
    plt.ylim(-30,30)
    
    clear_output(wait = True)
    display(fig)            # Reset display
    fig.clear()

# %%
def generate_phase_space(x_lim, v_lim, grid_size,mu):

    x = np.linspace(x_lim[0], x_lim[1], grid_size)
    v = np.linspace(v_lim[0], v_lim[1], grid_size)
    
    X, V = np.meshgrid(x, v)
    
    dX, dV = VDPO(mu,X, V)
    
    return X, V, dX, dV

x_lim = (-20, 20)
v_lim = (-20, 20)
grid_size = 20
X, V, dX, dV = generate_phase_space(x_lim, v_lim, grid_size,10)
fig, axs = plt.subplots(2, 1, figsize=(8, 10))  # Two rows, one column
t,x,v=RK4(VDPO,20,100000,10)

axs[0].plot(x,v, label='Sample trajectory', c='C2')
    
axs[0].quiver(X, V, dX, dV, color='C0')
axs[0].set_title('Quiver Plot of Phase Diagram')
axs[0].set_xlabel(r'$x$')
axs[0].set_ylabel(r'$\dot{x}$')

axs[1].plot(x,v, label='Sample trajectory', c='C2')
axs[1].streamplot(X, V, dX, dV, color='C1')
axs[1].set_title('Stream Plot of  Phase Diagram')
axs[1].set_xlabel(r'$x$')
axs[1].set_ylabel(r'$\dot{x}$');

# %%
#Doing an enrgy Analysis:
#Looking at only mu=1
trk4,xrk4,vrk4=np.array(RK4(VDPO,50,100000,1))
plt.plot(trk4,xrk4,label='position')
plt.plot(trk4,vrk4,label='velocity')
plt.legend()
plt.show()

# %%
plt.plot(xrk4,vrk4)

# %%
plt.plot(trk4,0.5*xrk4**2,label='Potential Change')
plt.plot(trk4,0.5*vrk4**2,label='Kinaetic Change')
plt.legend()
plt.show()

# %%
plt.plot(trk4,0.5*vrk4**2 + 0.5*xrk4**2,label='Total Change')
plt.legend()
plt.show()

# %%
#NEXT STEP: LOOK AT DAMPED DRIVEN
def VDPOD(a,mu,t,X, V):
    dX = V
    dV = mu*(1-X**2)*V - X + 1*np.sin(a*t) 
    return dX, dV

def RK4(f, tf, n, mu, a):
    v = 0
    x = 1
    X_values = []
    V_values = []
    h = tf / n
    tpoints = np.arange(0, tf, h)
    for t in tpoints:
        X_values.append(x)
        V_values.append(v)
        
        k1x, k1v = f(a, mu, t, x, v)
    
        k2x, k2v = f(a, mu, t + h / 2, x + h / 2 * k1x, v + h / 2 * k1v)
    
        k3x, k3v = f(a, mu, t + h / 2, x + h / 2 * k2x, v + h / 2 * k2v)
    
        k4x, k4v = f(a, mu, t + h, x + h * k3x, v + h * k3v)
    
        x += h / 6 * (k1x + 2 * k2x + 2 * k3x + k4x)
        v += h / 6 * (k1v + 2 * k2v + 2 * k3v + k4v)
        
    return tpoints, X_values, V_values

# %%
#Analysis for a while mu is 1
As=[0.01,0.1,0.3,0.5,0.7,0.9,1,5,10,15]
for a in As:
    trk4,xrk4,vrk4=RK4(VDPOD,50,1000,1,a)
    plt.plot(trk4,xrk4,label=f'a is {a}')
plt.legend()
plt.show()

# %%
#Animation as to how a changes while mu is 1:
As=[0.01,0.1,0.5,0.7,0.9,1,5,10,15,20]
fig = plt.figure(figsize=(8,8))
# Generate and save images
for a in As:
    trk4,xrk4,vrk4=RK4(VDPOD,10,1000,1,a)
    plt.plot(trk4,xrk4)
    plt.title(f'a is {a}')
    plt.xlabel('t')
    plt.ylabel('x')
    time.sleep(0.01)
    #plt.ylim(-30,30)
    
    clear_output(wait = True)
    display(fig)            # Reset display
    fig.clear()

# %%
As=[0.01,0.1,0.5,1,5,10,15]
for a in As:
    trk4,xrk4,vrk4=RK4(VDPOD,10,1000,1.5,a)
    plt.plot(trk4,vrk4,label=f'a is {a}')
plt.legend()
plt.show()

# %%
As=[0.01,0.1,0.5,1,5,10,15,20]
fig = plt.figure(figsize=(8,8))
# Generate and save images
for a in As:
    trk4,xrk4,vrk4=RK4(VDPOD,10,1000,1,a)
    plt.plot(trk4,vrk4)
    plt.title(f'a is {a}')
    plt.xlabel('t')
    plt.ylabel('v')
    time.sleep(0.01)
    #plt.ylim(-30,30)
    
    clear_output(wait = True)
    display(fig)            # Reset display
    fig.clear()

# %%
#Doing an enrgy Analysis:
#Looking at only mu=1 a=1
trk4,xrk4,vrk4=np.array(RK4(VDPOD,50,100000,1,1))
plt.plot(trk4,xrk4,label='position')
plt.plot(trk4,vrk4,label='velocity')
plt.legend()
plt.show()

# %%
plt.plot(trk4,0.5*xrk4**2,label='Potential Change')
plt.plot(trk4,0.5*vrk4**2,label='Kinaetic Change')
plt.legend()
plt.show()

# %%
plt.plot(trk4,0.5*vrk4**2 + 0.5*xrk4**2,label='Total Change')
plt.legend()
plt.show()

# %%
def generate_phase_space(t,x_lim, v_lim, grid_size,mu):

    x = np.linspace(x_lim[0], x_lim[1], grid_size)
    v = np.linspace(v_lim[0], v_lim[1], grid_size)
    
    X, V = np.meshgrid(x, v)
    
    dX, dV = VDPOD(a,mu,t,X, V)
    
    return X, V, dX, dV
x_lim = (-5, 5)
v_lim = (-5, 5)
grid_size = 20
mu= 1
a = 1
tf = 20
n = 1000
X=[]
V=[]
dX=[]
dV=[]
for i, t in enumerate(np.linspace(0.1, 50, 100)):
    #t = i * tf / n_frames
    x,v,dx,dv = generate_phase_space(t, x_lim, v_lim, grid_size, mu)
    X.append(x)
    V.append(v)
    dX.append(dx)
    dV.append(dv)

fig = plt.figure(figsize=(8,8))

for i, t in enumerate(np.linspace(0.1, 50, 100)):

    fig, axs = plt.subplots(1, 1, figsize=(8, 10))  
    axs.streamplot(X[i], V[i], dX[i], dV[i], color='C1')
    axs.set_title('Stream Plot of Phase Diagram')
    axs.set_xlabel(r'$x$')
    axs.set_ylabel(r'$\dot{x}$')
    print('The current value of i is:', i)
    time.sleep(0.1)
    
    clear_output(wait = True)
    display(fig)            # Reset display
    fig.clear()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[101], line 35
#      32 for i, t in enumerate(np.linspace(0.1, 50, 100)):
#      34     fig, axs = plt.subplots(1, 1, figsize=(8, 10))
# ---> 35     axs.streamplot(X[i], V[i], dX[i], dV[i], color='C1')
#      36     axs.set_title('Stream Plot of Phase Diagram')
#      37     axs.set_xlabel(r'$x$')
#
# File ~\anaconda3\lib\site-packages\matplotlib\__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~\anaconda3\lib\site-packages\matplotlib\streamplot.py:155, in streamplot(axes, x, y, u, v, density, linewidth, color, cmap, norm, arrowsize, arrowstyle, minlength, transform, zorder, start_points, maxlength, integration_direction, broken_streamlines)
#     153 if mask[ym, xm] == 0:
#     154     xg, yg = dmap.mask2grid(xm, ym)
# --> 155     t = integrate(xg, yg, broken_streamlines)
#     156     if t is not None:
#     157         trajectories.append(t)
#
# File ~\anaconda3\lib\site-packages\matplotlib\streamplot.py:484, in _get_integrator.<locals>.integrate(x0, y0, broken_streamlines)
#     482     return None
#     483 if integration_direction in ['both', 'backward']:
# --> 484     s, xyt = _integrate_rk12(x0, y0, dmap, backward_time, maxlength,
#     485                              broken_streamlines)
#     486     stotal += s
#     487     xy_traj += xyt[::-1]
#
# File ~\anaconda3\lib\site-packages\matplotlib\streamplot.py:589, in _integrate_rk12(x0, y0, dmap, f, maxlength, broken_streamlines)
#     587 yi += dy2
#     588 try:
# --> 589     dmap.update_trajectory(xi, yi, broken_streamlines)
#     590 except InvalidIndexError:
#     591     break
#
# File ~\anaconda3\lib\site-packages\matplotlib\streamplot.py:310, in DomainMap.update_trajectory(self, xg, yg, broken_streamlines)
#     308 if not self.grid.within_grid(xg, yg):
#     309     raise InvalidIndexError
# --> 310 xm, ym = self.grid2mask(xg, yg)
#     311 self.mask._update_trajectory(xm, ym, broken_streamlines)
#
# File ~\anaconda3\lib\site-packages\matplotlib\streamplot.py:288, in DomainMap.grid2mask(self, xi, yi)
#     286 def grid2mask(self, xi, yi):
#     287     """Return nearest space in mask-coords from given grid-coords."""
# --> 288     return round(xi * self.x_grid2mask), round(yi * self.y_grid2mask)
#
# KeyboardInterrupt:

# %%
# Out:
# Requirement already satisfied: ffmpeg in c:\users\49176\anaconda3\lib\site-packages (1.4)

# %% [markdown]
# ## Results and Discussion

# %% [markdown]
# _(What did you find when you carried out your methods? Some of your code related to presenting results/figures/data may be replicated from the methods section or may only be present in
# this section.
# All of the plots that you plan on using for your presentation should be present in this section)_

# %% [markdown]
# ##  Conclusion and Perspectives

# %% [markdown]
# _(What did you learn from your results? What obstacles did you run into? What would you do differently next time? Clearly provide quantitative answers to your question(s)?  At least one of your questions should be answered with numbers.  That is, it is not sufficient to answer "yes" or "no", but rather to say something quantitative such as variable 1 increased roughly 10% for every 1 year increase in variable 2.)_

# %% [markdown]
# ## References

# %% [markdown]
# _(List the source(s) for any data and/or literature cited in your project.  Ideally, this should be formatted using a formal citation format (MLA or APA or other, your choice!).
# Multiple free online citation generators are available such as <a href="http://www.easybib.com/style">http://www.easybib.com/style</a>.
# **Important:** if you use **any** code that you find on the internet for your project you **must** cite it or you risk losing most/all of the points for you project.)_

# %% [markdown]
# ##  Appendices
